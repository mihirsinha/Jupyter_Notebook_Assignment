# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:b6d3ec62-a890-485f-8b41-5c11516af433.png)

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:b8cff402-45b5-487b-a584-66dd6d89dd0f.png)

# %% [markdown]
# ## Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Python
# 2. R
# 3. Ruby

# %% [markdown]
# ![4-dslanguages.png](attachment:051d0632-3fd0-44c6-a220-f099eae3c6f5.png)

# %% [markdown]
# ## Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# 1. NumPy.
# 2. Keras.
# 3. Pandas.
# 4. PyTorch.
# 5. SciPy.

# %% [markdown]
# ![5-dslibraries.png](attachment:0c03be90-e152-4f6b-b7f9-f727af7b8b14.png)

# %% [markdown]
# ## Data Science Tools

# %% [markdown]
# | Data Science Tools |
# |---|
# | Hadoop |
# | Jupyter notebook |
# | R studio |

# %% [markdown]
# ![6-dstools.png](attachment:2f146da7-38d3-407d-9cb4-962319a9cab2.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![7-introarithmetic.png](attachment:378b44ab-83d7-4ef1-80f5-82462103891e.png)

# %%
#This a simple arithmetic expression to mutiply then add integers
print((3*4)+5)
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:6d0ae6b3-309a-480c-8b74-ccef39241ace.png)

# %%
#This will convert 200 minutes to hours by diving by 60
print(200/60)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:fcbc12b1-cf98-4b1e-9eaf-140ba8234904.png)

# %% [markdown]
# ## __Objectives:__

# %% [markdown]
# * Create a markdown cell with the title of the notebook. (1 pt)
#
# * Create a markdown cell for an introduction. (1 pt)
#
# * Create a markdown cell to list data science languages. (3 pts)
#
# * Create a markdown cell to list data science libraries. (3 pts)
#
# * Create a markdown cell with a table of Data Science tools. (3 pts)

# %% [markdown]
# ![10-objectives.png](attachment:86eb8bd5-a1fb-49d1-8c81-540744635bf6.png)

# %% [markdown]
# ## Author
# Mihir Sinha

# %% [markdown]
# ![11-authordetails.png](attachment:bc38d4a7-d4e3-43df-b8b1-f4b350259b69.png)
